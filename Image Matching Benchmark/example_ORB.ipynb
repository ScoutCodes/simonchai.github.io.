# %%
import os
import cv2
from methods.local_feature.orb import run
import numpy as np
from types import SimpleNamespace  # For mock configuration
from third_party.colmap.scripts.python.read_write_model import qvec2rotmat
from utils.path_helper import get_fullpath_list
import matplotlib.pyplot as plt

# %%
def convert_to_cv2_keypoints(keypoints):
    return [cv2.KeyPoint(x=kp[0], y=kp[1], _size=1) for kp in keypoints]

# %%
def draw_keypoints_on_image(image, keypoints):
    # Convert keypoints to OpenCV KeyPoint objects
    opencv_keypoints = convert_to_cv2_keypoints(keypoints)

    # Draw keypoints on the image
    output_image = cv2.drawKeypoints(image, opencv_keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

    return output_image

# %%
# Configuration for keypoint extraction
cfg = SimpleNamespace()
cfg.method_dict = {
    'config_common': {
        'num_keypoints': 500,
        'keypoint': 'orb-def'
    }
}

# Directories and file paths
data_dir = "../data/phototourism/piazza_san_marco"
output_dir = "../data/phototourism/piazza_san_marco/output/orb"
os.makedirs(output_dir, exist_ok=True)

image_list_path = os.path.join(data_dir, "images.txt")
if not os.path.exists(image_list_path):
    raise FileNotFoundError(f"{image_list_path} not found.")

# Load image paths
with open(image_list_path, "r") as f:
    image_list = [os.path.normpath(os.path.join(data_dir, "images", line.strip())) for line in f]

print(f"Loaded {len(image_list)} images.")

# Extract keypoints and descriptors for all images
features = {}
for i, image_path in enumerate(image_list):
    features[i] = run(image_path, cfg)
    print(f"Image {i + 1}: {len(features[i]['kp'])} keypoints detected.")

    # Save keypoints visualization for each image
    image = cv2.imread(image_path)
    image_with_keypoints = draw_keypoints_on_image(image, features[i]['kp'])
    keypoints_output_path = os.path.join(output_dir, f"image_{i + 1}_keypoints.jpg")
    cv2.imwrite(keypoints_output_path, image_with_keypoints)

print("Keypoints detection completed and saved.")

# Perform matching for every pair of images
num_images = len(image_list)
matches_results = []

for i in range(num_images // 2):
    # Pair indices
    idx1 = i * 2
    idx2 = idx1 + 1

    # Descriptors
    desc1 = np.array(features[idx1]['descs'], dtype=np.uint8)
    desc2 = np.array(features[idx2]['descs'], dtype=np.uint8)

    # FLANN Matcher
    index_params = dict(algorithm=6, table_number=6, key_size=12, multi_probe_level=2)
    search_params = dict(checks=50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(desc1, desc2, k=2)

    # Separate matches into good and bad
    good_matches = []
    bad_matches = []
    for m, n in matches:
        if m.distance < 0.7 * n.distance:
            good_matches.append(m)
        else:
            bad_matches.append(m)

    # RANSAC-based geometric verification
    if len(good_matches) < 8:  # 8 points is required for fundamental matrix estimation
        print(f"Insufficient matches for pair {i + 1}. Skipping.")
        continue

    pts1 = np.float32([features[idx1]['kp'][m.queryIdx] for m in good_matches])
    pts2 = np.float32([features[idx2]['kp'][m.trainIdx] for m in good_matches])
    F, mask = cv2.findFundamentalMat(pts1, pts2, cv2.FM_RANSAC, 1.0, 0.99)

    if F is None or mask is None:
        print(f"RANSAC failed for pair {i + 1}. Skipping.")
        continue
    
    # Save the fundamental matrix
    fundamental_matrix_txt_path = os.path.join(output_dir, f"pair_{i + 1}_fundamental_matrix.txt")
    np.savetxt(fundamental_matrix_txt_path, F, fmt='%.6f', header="Fundamental Matrix")
    print(f"Fundamental matrix for pair {i + 1} saved to {fundamental_matrix_txt_path}.")

    # Extract inliers
    inlier_matches = [good_matches[k] for k in range(len(good_matches)) if mask[k]]
    print(f"Pair {i + 1}: {len(inlier_matches)} inliers after RANSAC.")

    # Visualize matches
    image1 = cv2.imread(image_list[idx1])
    image2 = cv2.imread(image_list[idx2])

    # Custom visualization: Draw good matches in blue, bad matches in red
    img_matches = image1.copy()
    h1, w1 = image1.shape[:2]
    h2, w2 = image2.shape[:2]
    combined_img = np.zeros((max(h1, h2), w1 + w2, 3), dtype=np.uint8)
    combined_img[:h1, :w1] = image1
    combined_img[:h2, w1:] = image2

    # Draw lines for matches
    for m in bad_matches:  # Bad matches in red
        pt1 = tuple(map(int, features[idx1]['kp'][m.queryIdx]))
        pt2 = tuple(map(int, features[idx2]['kp'][m.trainIdx] + np.array([w1, 0])))
        cv2.line(combined_img, pt1, pt2, (0, 0, 255), 1)

    for m in good_matches:  # Good matches in blue
        pt1 = tuple(map(int, features[idx1]['kp'][m.queryIdx]))
        pt2 = tuple(map(int, features[idx2]['kp'][m.trainIdx] + np.array([w1, 0])))
        cv2.line(combined_img, pt1, pt2, (255, 0, 0), 2)

    matches_output_path = os.path.join(output_dir, f"pair_{i + 1}_matches.jpg")
    cv2.imwrite(matches_output_path, combined_img)

    # Store the results
    matches_results.append({
        "pair_index": i + 1,
        "num_inliers": len(inlier_matches),
        "fundamental_matrix": F
    })
# Out:
# Loaded 100 images.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\01688348_12300730234.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\01688348_12300730234.jpg
# Image 1: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\02577600_6870111213.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\02577600_6870111213.jpg
# Image 2: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\03449722_3316267248.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\03449722_3316267248.jpg
# Image 3: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\03693106_384020886.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\03693106_384020886.jpg
# Image 4: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\03929605_4794028100.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\03929605_4794028100.jpg
# Image 5: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\04017487_9005602998.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\04017487_9005602998.jpg
# Image 6: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\05446260_7175726639.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\05446260_7175726639.jpg
# Image 7: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\08020749_4084672329.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\08020749_4084672329.jpg
# Image 8: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\15287021_2386110848.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\15287021_2386110848.jpg
# Image 9: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\17749873_4312851244.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\17749873_4312851244.jpg
# Image 10: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\17910261_2170412992.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\17910261_2170412992.jpg
# Image 11: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\18084381_5145286184.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\18084381_5145286184.jpg
# Image 12: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\18426818_4117109073.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\18426818_4117109073.jpg
# Image 13: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\18522932_1886959999.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\18522932_1886959999.jpg
# Image 14: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\18627786_5929294590.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\18627786_5929294590.jpg
# Image 15: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\19394510_8649812072.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\19394510_8649812072.jpg
# Image 16: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\19723085_13560889295.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\19723085_13560889295.jpg
# Image 17: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\20308172_3751782049.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\20308172_3751782049.jpg
# Image 18: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\20649592_384001953.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\20649592_384001953.jpg
# Image 19: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images\20659768_370983914.jpg
# Attempting to load image: ..\data\phototourism\piazza_san_marco\images\20659768_370983914.jpg
# Image 20: 500 keypoints detected.
# Attempting to load image from: ..\data\phototourism\piazza_san_marco\images
saved to ../data/phototourism/piazza_san_marco/output/orb\pair_12_fundamental_matrix.txt.
# Pair 12: 28 inliers after RANSAC.
# RANSAC failed for pair 13. Skipping.
# RANSAC failed for pair 14. Skipping.
# Insufficient matches for pair 15. Skipping.
# Fundamental matrix for pair 16 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_16_fundamental_matrix.txt.
# Pair 16: 26 inliers after RANSAC.
# Insufficient matches for pair 17. Skipping.
# Insufficient matches for pair 18. Skipping.
# Fundamental matrix for pair 19 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_19_fundamental_matrix.txt.
# Pair 19: 16 inliers after RANSAC.
# Fundamental matrix for pair 20 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_20_fundamental_matrix.txt.
# Pair 20: 34 inliers after RANSAC.
# Fundamental matrix for pair 21 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_21_fundamental_matrix.txt.
# Pair 21: 29 inliers after RANSAC.
# Insufficient matches for pair 22. Skipping.
# Fundamental matrix for pair 23 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_23_fundamental_matrix.txt.
# Pair 23: 23 inliers after RANSAC.
# Fundamental matrix for pair 24 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_24_fundamental_matrix.txt.
# Pair 24: 12 inliers after RANSAC.
# Insufficient matches for pair 25. Skipping.
# Fundamental matrix for pair 26 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_26_fundamental_matrix.txt.
# Pair 26: 23 inliers after RANSAC.
# Fundamental matrix for pair 27 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_27_fundamental_matrix.txt.
# Pair 27: 15 inliers after RANSAC.
# Insufficient matches for pair 28. Skipping.
# Fundamental matrix for pair 29 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_29_fundamental_matrix.txt.
# Pair 29: 7 inliers after RANSAC.
# Fundamental matrix for pair 30 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_30_fundamental_matrix.txt.
# Pair 30: 19 inliers after RANSAC.
# Insufficient matches for pair 31. Skipping.
# Insufficient matches for pair 32. Skipping.
# Fundamental matrix for pair 33 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_33_fundamental_matrix.txt.
# Pair 33: 32 inliers after RANSAC.
# Insufficient matches for pair 34. Skipping.
# Insufficient matches for pair 35. Skipping.
# Insufficient matches for pair 36. Skipping.
# Fundamental matrix for pair 37 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_37_fundamental_matrix.txt.
# Pair 37: 18 inliers after RANSAC.
# Insufficient matches for pair 38. Skipping.
# Insufficient matches for pair 39. Skipping.
# Fundamental matrix for pair 40 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_40_fundamental_matrix.txt.
# Pair 40: 14 inliers after RANSAC.
# Insufficient matches for pair 41. Skipping.
# Fundamental matrix for pair 42 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_42_fundamental_matrix.txt.
# Pair 42: 33 inliers after RANSAC.
# Insufficient matches for pair 43. Skipping.
# Fundamental matrix for pair 44 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_44_fundamental_matrix.txt.
# Pair 44: 17 inliers after RANSAC.
# Fundamental matrix for pair 45 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_45_fundamental_matrix.txt.
# Pair 45: 17 inliers after RANSAC.
# Fundamental matrix for pair 46 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_46_fundamental_matrix.txt.
# Pair 46: 27 inliers after RANSAC.
# Insufficient matches for pair 47. Skipping.
# Insufficient matches for pair 48. Skipping.
# Insufficient matches for pair 49. Skipping.
# Fundamental matrix for pair 50 saved to ../data/phototourism/piazza_san_marco/output/orb\pair_50_fundamental_matrix.txt.
# Pair 50: 27 inliers after RANSAC.
